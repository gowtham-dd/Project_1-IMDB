# %%
# %pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

connection = mysql.connector.connect(
  host = "gateway01.ap-southeast-1.prod.aws.tidbcloud.com",
  port = 4000,
  user = "4PFhDQQc2yhfCUH.root",
  password = "tzNB9UAMnXNidi62",
  database = "sampleTable",

)
mycursor = connection.cursor(buffered=True)

# %%
print(df.columns)  # Check the exact column names
# Out:
# Index(['Title', 'Genre', 'Duration', 'Rating', 'Voting'], dtype='object')

# %%
import pandas as pd
import numpy as np

mycursor = connection.cursor(buffered=True)

# Read CSV
df = pd.read_csv("D:\Data Science\Project 1 IMDB\merged_cleaned_movies.csv")

# Replace NaN values with NULL
df = df.replace({np.nan: None})

# Insert data into the table
for _, row in df.iterrows():
    mycursor.execute(
        "INSERT INTO movies_database.movies (Title, Genre, Duration, Rating, Voting) VALUES (%s, %s, %s, %s, %s)", 
        (row["Title"], row["Genre"], row["Duration"], row["Rating"], row["Voting"])
    )

connection.commit()
mycursor.close()
connection.close()
print("✅ Data uploaded successfully!")
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\D'
# <>:7: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\dell\AppData\Local\Temp\ipykernel_11944\1293475694.py:7: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv("D:\Data Science\Project 1 IMDB\merged_cleaned_movies.csv")
# ✅ Data uploaded successfully!

# %%
# %pip install tabulate
mycursor.execute("SELECT * FROM movies_database.movies")
out=mycursor.fetchall()#out is a variable tht fetch all details
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# +-----------------------------------------------------------------------------------------+----------+------------+----------+----------+
# | Title                                                                                   | Genre    | Duration   |   Rating | Voting   |
# |-----------------------------------------------------------------------------------------+----------+------------+----------+----------|
# | Dune: Part Two                                                                          | Action   | 2h 46m     |      8.5 | 610K     |
# | Venom: The Last Dance                                                                   | Action   | 1h 50m     |      6   | 105K     |
# | Gladiator II                                                                            | Action   | 2h 28m     |      6.6 | 213K     |
# ...
